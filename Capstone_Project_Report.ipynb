# %% [markdown]
# ## Location Selection for Delivery Locker for Online Retailers
# #### Executive Summary
# Due to the rise in the online shopping, the prevalence of home deliveries has skyrocketed leading to an increase in package theft. The main purpose of this project is to address this problem by selecting the appropriate location to set up a delivery locker for the online retailer. Using Brooklyn borough as an example case study, K-means algorithm was applied to Brooklyn borough neighborhoods dataset and cluster into 5 groups based on the 10 most common venue feature. Finally, the appropriate recommended location for the delivery locker is identified for each Neighborhood.
# #### Introduction
# Online shopping has become a common phenomenon and part of consumer's daily life. Recently, consumer spending online is on the rise, and the US online sales revenue is expected to reach \$523 billion by 2020 [1]. The increase in online shopping has resulted in a significant rise in the frequency of home deliveries, so do package theft is increasing exponentially [2]. MailHaven an IoT company reported that 1 billion packages per year aren't delivered on the first try [1]. Most packages that don't fit into the mailboxes can't be left alone outside because they can be damaged or destroyed by bad weather or even stolen. According to the August Home Package Theft Report (2016), about 11 million U.S. homeowners have had a package stolen within the past, with a value close to \$200. Package theft has become a really big concern for both the customers and the retailers. About 53% of packages left on the doorsteps or porch are stolen and 75% of these packages are stolen during the day [3]. To address this problem, retailer and third-party logistics company such as Amazon and UPS have resulted to the use of delivery locker located at a convenience store with customer's neighborhood, where packages can be kept securely before customer pick up. These delivery lockers have proven to help in reducing theft of delivered packages [4]. Therefore, in this project, we are going to use a machine learning technique to determine the best location for delivery lockers in different neighborhoods in Brooklyn Borough, New York.
# #### Method of Data Collection and Analysis
# This section presents the datasets used for this study and details of the methods used to perform our analysis. The data for this project is obtained from New York geodata from [5] and the Foursquare location data to solve the business problem discussed above. First, Brooklyn borough neighborhood addresses are converted into their equivalent latitude and longitude values retrieved from New York geodata using Pandas library in Python. Table 1 shows the first 5 examples of a dataset comprising of   Borough, Neighborhood, Latitude, and Longitude of 70 Brooklyn borough neighborhoods.
#
# <center> Table 1: Examples dataset of Brooklyn Neighborhood Coordinates</center>
#
#  |**Borough**|**Neighborhood**|**Latitude**|**Longitude**
# :-----:|:-----:|:-----:|:-----:|:-----:
# 1|Brooklyn|Bay Ridge|40.625801|-74.030621
# 2|Brooklyn|Bensonhurst|40.611009|-73.99518
# 3|Brooklyn|Sunset Park|40.645103|-74.010316
# 4|Brooklyn|Greenpoint|40.730201|-73.954241
# 5|Brooklyn|Gravesend|40.59526|-73.973471
#
#
# Using the Folium library, Figure 1 shows the visualization of the 70 neighborhoods in Brooklyn borough, New York City represented by the blue circles.
#
#  <!---
# ![map_brooklyn_.jpg](attachment:map_brooklyn_n.png))
# -->
# <img src="map_brooklyn_n.png" />
# <center> Figure 1: Map showing Brooklyn Neighborhoods </center>
#
# Then, the Foursquare API is used to explore neighborhoods in Brooklyn borough, New York City. Using the explore function, the most common venue categories within a radius of 500 meters is extracted for each Brooklyn neighborhood and the number of returned venues by Foursquare API is limited to 100. Table 2 presents the first 5 venues of dataset returned.
#
# <center>Table 2: First 5 Examples of Dataset of Brooklyn Neighborhood with Venue Categories</center>
#
#  |**Neighborhood**|**Neighborhood Latitude**|**Neighborhood Longitude**|**Venue**|**Venue Latitude**|**Venue Longitude**|**Venue Category**
# :-----:|:-----:|:-----:|:-----:|:-----:|:-----:|:-----:|:-----:
# 1|Bay Ridge|40.625801|-74.030621|Pilo Arts Day Spa and Salon|40.624748|-74.030591|Spa
# 2|Bay Ridge|40.625801|-74.030621|Cocoa Grinder|40.623967|-74.030863|Juice Bar
# 3|Bay Ridge|40.625801|-74.030621|Bagel Boy|40.627896|-74.029335|Bagel Shop
# 4|Bay Ridge|40.625801|-74.030621|XIN|40.625082|-74.030494|Chinese Restaurant
# 5|Bay Ridge|40.625801|-74.030621|Areo Ristorante|40.624415|-74.030782|Italian Restaurant
#
#
# Now, the venue categories feature is used to group the neighborhoods into clusters. The k-means clustering algorithm is employed to perform this task. Finally, the Folium library is utilized to visualize the neighborhoods in Brooklyn borough and their emerging clusters.
# Results and Discussion
# Table 3 shows the summary of the number of venues returned for the neighborhood using the Foursquare API.
#
#  <center> Table 3: Descriptive Statistics of the Number of Venues Returned for each Neighborhood</center>
#
# | Statistics    | Number of Venues Returned |
# |---------------|---------------------------|
# | count         | 70                        |
# | mean          | 40.11                     |
# | std           | 31.40                     |
# | min           | 2                         |
# | 2nd Quartile  | 16.25                     |
# | Median        | 27                        |
# | 3rd  Quartile | 65.25                     |
# | max           | 100                       |
#
#
# From Table 3 above, we can see that the minimum number of venues return for the neighborhoods is 2, an average of 40.11 and a maximum of 100 which is the limit. The 10 most common venue categories feature is used for the K-means clustering analyze for grouping the neighborhoods based on their characteristics and the result is shown in Figure 2.
#
# <!--
# ![Cluster_Result_n.png](attachment:Cluster_Result_n.png)
# -->
# <img src="Cluster_Result_n.png" />
# <center> Figure 2: Map showing the resulting Neighborhood clusters</center>
#
# To find suitable locations to recommend for delivery locker location, we examine each cluster in order to recommend the appropriate type of venue for a delivery locker in each neighborhood. For example, Greenpoint belongs to cluster 5 (label is cluster 4 because of indexing in python start from 0) and can be deduced that one of the Boutique in that neighborhood is a good fit for a delivery locker. This cluster generally has grocery stores in their top ten most common places which are great candidate location for a secure delivery locker. Therefore, the decision maker may consider other qualitative factors such as integrity of the store owner, security and type of contractual agreement for store owner compensation etc.
# #### Conclusion
# This project explores Brooklyn borough neighborhoods using the Foursquare API and utilizes K-means machine learning algorithm to group neighborhoods into clusters. These clusters are based on the 10 most common venue categories feature extracted from Foursquare location data. This information can now be used in making selection decision for a delivery locker for each neighborhood by the decision maker. For all Neighborhood in each cluster, Pharmacy, Supermarket, Discount Store, Wine Shop, Grocery Store, Department Store, Bookstore, Convenience Store and even Pizza place seems to be viable locations for delivery lockers.
# #### Reference
# 1.	https://mailhaven.co/snail-mail-smart-mail/
# 2.	https://www.inc.com/john-white/tired-of-getting-your-packages-stolen-heres-what-to-do.html
# 3.	https://august.com/wp-content/uploads/2016/10/August-Package-Theft-Report-FINAL-102516.pdf
# 4.	https://www.pymnts.com/news/retail/2017/package-locker-systems-luxer-one-package-delivery/
# 5.	https://geo.nyu.edu/catalog/nyu_2451_34572

# %% [markdown]
# ### Thank you for reading my project!
#
# This notebook was created by [Leke Ogunranti](https://www.linkedin.com/in/leke-ogunranti-mba-09077049/) as a project report for Applied Data Science Capstone as part of IBM Data Science Professional Certificate. I hope you found this project interesting and worth further study. Feel free to contact me if you have any questions!

# %%
from IPython.display import Image, display
display(Image(filename='Cluster_Result_n.png', embed=True))
print('Figure 2: Map showing the resulting Neighborhood clusters')
# Out:
# Figure 2: Map showing the resulting Neighborhood clusters

# %%
from IPython.display import Image, display
display(Image(filename='map_brooklyn_n.png', embed=True))
print('Figure 1: Map showing Brooklyn Neighborhoods')
# Out:
# Figure 1: Map showing Brooklyn Neighborhoods
